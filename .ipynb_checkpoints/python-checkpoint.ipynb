# %%
import matplotlib.pyplot as plt
import numpy as np
import math


def serie_harmonique(n):
    inv = 1/np.arange(1, 100_000)
    return [sum(inv[:n]) for n in range(1, 100_001)]

# Plotting the logarithmic divergence and harmonic series
x = np.arange(1, 100_000)
plt.plot(x, np.log(x))
plt.plot(x, 
plt.xlabel("n")
plt.ylabel("H(n)")
plt.title("Divergence logarithmique et constante d'Euler-Mascheroni")
plt.legend(["ln(n)", "H(n)"])
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()
# Out:
#   Cell In[8], line 13
#     plt.plot(x,
#             ^
# SyntaxError: '(' was never closed

# %%
import numpy

# %%
np.log(np.arange(1, 100_000))
# Out:
# array([ 0.        ,  0.69314718,  1.09861229, ..., 11.51289546,
#        11.51290546, 11.51291546], shape=(99999,))

# %%
1/np.arange(1, 100_000)
# Out:
# array([1.00000000e+00, 5.00000000e-01, 3.33333333e-01, ...,
#        1.00003000e-05, 1.00002000e-05, 1.00001000e-05], shape=(99999,))
